# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
yash = pd.read_csv(r"C:\Users\YASH KHADTARE\FERGUSSON\SEM 3\Final year Project\FINAL_DATA_YASH.csv")
anuradha= pd.read_csv(r"C:\Users\YASH KHADTARE\FERGUSSON\SEM 3\Final year Project\FINAL_DATA_ANURADHA.csv")
mahesh = pd.read_csv(r"C:\Users\YASH KHADTARE\FERGUSSON\SEM 3\Final year Project\FINAL_DATA_MAHESH.csv")

# %%
df = pd.concat([yash, anuradha , mahesh] , axis = 0)
df
# Out:
#        Brand_name                           model_name      price  \
# 0         SAMSUNG               SAMSUNG Galaxy Z Fold5  ₹1,84,999
# 1         SAMSUNG               SAMSUNG Galaxy Z Fold5  ₹1,84,999
# 2         SAMSUNG               SAMSUNG Galaxy Z Fold5  ₹1,84,999
# 3         SAMSUNG               SAMSUNG Galaxy Z Fold5  ₹1,84,999
# 4         SAMSUNG            SAMSUNG Galaxy Z Fold4 5G  ₹1,64,999
# ...           ...                                  ...        ...
# 118289      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
# 118290      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
# 118291      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
# 118292      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
# 118293      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
#
#                                                    review  rating_by_reviewer  \
# 0       Great phone, really good looking and specimen ...                   5
# ...

# %%
df['Brand_name'].unique()
# Out:
# array(['SAMSUNG', 'VIVO', 'REALME', 'POCO', 'OPPO', 'MOTOROLA', 'GOOGLE',
#        'NOTHING', 'MOTO', 'XIAOMI', 'MI', 'REDMI', 'APPLE'], dtype=object)

# %%
df
# Out:
#        Brand_name                           model_name      price  \
# 0         SAMSUNG               SAMSUNG Galaxy Z Fold5  ₹1,84,999
# 1         SAMSUNG               SAMSUNG Galaxy Z Fold5  ₹1,84,999
# 2         SAMSUNG               SAMSUNG Galaxy Z Fold5  ₹1,84,999
# 3         SAMSUNG               SAMSUNG Galaxy Z Fold5  ₹1,84,999
# 4         SAMSUNG            SAMSUNG Galaxy Z Fold4 5G  ₹1,64,999
# ...           ...                                  ...        ...
# 118289      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
# 118290      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
# 118291      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
# 118292      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
# 118293      APPLE  APPLE iPhone 5s (Space Grey, 16 GB)    ₹25,000
#
#                                                    review  rating_by_reviewer  \
# 0       Great phone, really good looking and specimen ...                   5
# ...

# %%
df.to_csv('REVIEW_with_SENTIMENTS.csv' ,  index = False)

# %% [markdown]
# # EXAMPLE of VISUALIZATION

# %%
df[df['Brand_name']=='SAMSUNG']['Sentiment'].value_counts()
plt.pie(df[df['Brand_name']=='SAMSUNG']['Sentiment'].value_counts() ,labels = ['POSITIVE','NEGATIVE'] , autopct=f"%.2f" )
plt.title("SAMSUNG SENTIMENT ANALYSIS on REVIEWS")
plt.show()

# %%
plt.pie(df[df['Brand_name']=='APPLE']['Sentiment'].value_counts() ,labels = ['POSITIVE','NEGATIVE'] , autopct=f"%.2f" )
plt.title("APPLE SENTIMENT ANALYSIS on REVIEWS")
plt.show()
